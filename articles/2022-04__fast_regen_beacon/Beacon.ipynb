# %%
import matplotlib.pyplot as mplt
fig, ax = mplt.subplots()
ax.plot([140, 350],[0,0],'-')
ax.plot([150,200,250,300],[0,0,0,0],'o')
ax.plot([180, 260, 340], [0,0,0], 'x')
ax.invert_xaxis()
ax.set_ybound([-1,1])
off = 7
ax.annotate('340', xy=(340, 0), xycoords='data', xytext=(340 + off,-0.3), textcoords='data', arrowprops=dict(arrowstyle="-"))
ax.annotate('260', xy=(260, 0), xycoords='data', xytext=(260 + off,-0.3), textcoords='data', arrowprops=dict(arrowstyle="-"))
ax.annotate('180', xy=(180, 0), xycoords='data', xytext=(180 + off,-0.3), textcoords='data', arrowprops=dict(arrowstyle="-"))
off = 7
ax.annotate('300', xy=(300, 0), xycoords='data', xytext=(300 + off,0.2), textcoords='data', arrowprops=dict(arrowstyle="-"))
ax.annotate('250', xy=(250, 0), xycoords='data', xytext=(250 + off,0.2), textcoords='data', arrowprops=dict(arrowstyle="-"))
ax.annotate('200', xy=(200, 0), xycoords='data', xytext=(200 + off,0.2), textcoords='data', arrowprops=dict(arrowstyle="-"))
ax.annotate('150', xy=(150, 0), xycoords='data', xytext=(150 + off,0.2), textcoords='data', arrowprops=dict(arrowstyle="-"))
off = 0
ax.annotate('Beacon resets effect', xy=(340, -0.3), xycoords='data', xytext=(340 + off,-0.8), textcoords='data', arrowprops=dict(arrowstyle="->"))
off = 10
ax.annotate('(skipped)', xy=(260, -0.3), xycoords='data', xytext=(260 + off,-0.65), textcoords='data', arrowprops=dict(arrowstyle="->"))
off = 45
ax.annotate('Beacon resets effect', xy=(180, -0.3), xycoords='data', xytext=(180 + off,-0.8), textcoords='data', arrowprops=dict(arrowstyle="->"))
# Out:
# Text(225, -0.8, 'Beacon resets effect')
